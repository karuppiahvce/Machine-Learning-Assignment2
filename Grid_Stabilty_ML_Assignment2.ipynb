# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    roc_auc_score,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef
)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-de96ee3f-76b7-44b9-8754-f6d782a3d857" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de96ee3f-76b7-44b9-8754-f6d782a3d857">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_name = list(uploaded.keys())[0]

data = pd.read_csv('/content/Grid stability test dataset.csv')

print("Dataset loaded successfully!")
print("Dataset size:", data.shape)
# Out:
# Dataset loaded successfully!
# Dataset size: (10000, 14)

# %%
data.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
print(data.columns)
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stab', 'stabf'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
print(data["stabf"].value_counts())
# Out:
# stabf
# unstable    6380
# stable      3620
# Name: count, dtype: int64

# %%
X = data.drop(["stab", "stabf"], axis=1)

y = data["stabf"]

print("Number of input features:", X.shape[1])
print("Number of samples:", X.shape[0])
# Out:
# Number of input features: 12
# Number of samples: 10000

# %%
encoder = LabelEncoder()

y = encoder.fit_transform(y)

print("Target classes:")
print(encoder.classes_)
# Out:
# Target classes:
# ['stable' 'unstable']

# %%
print("0 =", encoder.classes_[0])
print("1 =", encoder.classes_[1])
# Out:
# 0 = stable
# 1 = unstable

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 8000
# Testing samples: 2000

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

print("Feature scaling completed!")
# Out:
# Feature scaling completed!

# %%
logistic_model = LogisticRegression(max_iter=1000)

logistic_model.fit(X_train_scaled, y_train)

print("Logistic Regression model trained successfully!")
# Out:
# Logistic Regression model trained successfully!

# %%
logistic_prediction = logistic_model.predict(X_test_scaled)

logistic_probability = logistic_model.predict_proba(X_test_scaled)[:, 1]

print("Predictions completed!")
# Out:
# Predictions completed!

# %%
logistic_accuracy = accuracy_score(
    y_test,
    logistic_prediction
)

logistic_auc = roc_auc_score(
    y_test,
    logistic_probability
)

logistic_precision = precision_score(
    y_test,
    logistic_prediction
)

logistic_recall = recall_score(
    y_test,
    logistic_prediction
)

logistic_f1 = f1_score(
    y_test,
    logistic_prediction
)

logistic_mcc = matthews_corrcoef(
    y_test,
    logistic_prediction
)

# %%
print("LOGISTIC REGRESSION RESULTS")
print("--------------------------------")
print("Accuracy  :", round(logistic_accuracy, 4))
print("AUC Score :", round(logistic_auc, 4))
print("Precision :", round(logistic_precision, 4))
print("Recall    :", round(logistic_recall, 4))
print("F1 Score  :", round(logistic_f1, 4))
print("MCC Score :", round(logistic_mcc, 4))
# Out:
# LOGISTIC REGRESSION RESULTS
# --------------------------------
# Accuracy  : 0.82
# AUC Score : 0.892
# Precision : 0.8408
# Recall    : 0.8856
# F1 Score  : 0.8626
# MCC Score : 0.6039

# %%
decision_tree = DecisionTreeClassifier(
    random_state=42
)

decision_tree.fit(X_train, y_train)

print("Decision Tree trained successfully!")
# Out:
# Decision Tree trained successfully!

# %%
tree_prediction = decision_tree.predict(X_test)

tree_probability = decision_tree.predict_proba(X_test)[:, 1]

print("Decision Tree predictions completed!")
# Out:
# Decision Tree predictions completed!

# %%
tree_accuracy = accuracy_score(
    y_test,
    tree_prediction
)

tree_auc = roc_auc_score(
    y_test,
    tree_probability
)

tree_precision = precision_score(
    y_test,
    tree_prediction
)

tree_recall = recall_score(
    y_test,
    tree_prediction
)

tree_f1 = f1_score(
    y_test,
    tree_prediction
)

tree_mcc = matthews_corrcoef(
    y_test,
    tree_prediction
)

# %%
print("DECISION TREE RESULTS")
print("--------------------------------")
print("Accuracy  :", round(tree_accuracy, 4))
print("AUC Score :", round(tree_auc, 4))
print("Precision :", round(tree_precision, 4))
print("Recall    :", round(tree_recall, 4))
print("F1 Score  :", round(tree_f1, 4))
print("MCC Score :", round(tree_mcc, 4))
# Out:
# DECISION TREE RESULTS
# --------------------------------
# Accuracy  : 0.8495
# AUC Score : 0.8369
# Precision : 0.8818
# Recall    : 0.8824
# F1 Score  : 0.8821
# MCC Score : 0.6741

# %%
knn_model = KNeighborsClassifier(
    n_neighbors=5
)

knn_model.fit(X_train_scaled, y_train)

print("KNN model trained successfully!")
# Out:
# KNN model trained successfully!

# %%
knn_prediction = knn_model.predict(X_test_scaled)

knn_probability = knn_model.predict_proba(X_test_scaled)[:, 1]

print("KNN predictions completed!")
# Out:
# KNN predictions completed!

# %%
knn_accuracy = accuracy_score(
    y_test,
    knn_prediction
)

knn_auc = roc_auc_score(
    y_test,
    knn_probability
)

knn_precision = precision_score(
    y_test,
    knn_prediction
)

knn_recall = recall_score(
    y_test,
    knn_prediction
)

knn_f1 = f1_score(
    y_test,
    knn_prediction
)

knn_mcc = matthews_corrcoef(
    y_test,
    knn_prediction
)

# %%
print("K-NEAREST NEIGHBOUR RESULTS")
print("--------------------------------")
print("Accuracy  :", round(knn_accuracy, 4))
print("AUC Score :", round(knn_auc, 4))
print("Precision :", round(knn_precision, 4))
print("Recall    :", round(knn_recall, 4))
print("F1 Score  :", round(knn_f1, 4))
print("MCC Score :", round(knn_mcc, 4))
# Out:
# K-NEAREST NEIGHBOUR RESULTS
# --------------------------------
# Accuracy  : 0.8625
# AUC Score : 0.929
# Precision : 0.8547
# Recall    : 0.9451
# F1 Score  : 0.8977
# MCC Score : 0.698

# %%
naive_bayes = GaussianNB()

naive_bayes.fit(X_train, y_train)

print("Gaussian Naive Bayes trained successfully!")
# Out:
# Gaussian Naive Bayes trained successfully!

# %%
nb_prediction = naive_bayes.predict(X_test)

nb_probability = naive_bayes.predict_proba(X_test)[:, 1]

print("Naive Bayes predictions completed!")
# Out:
# Naive Bayes predictions completed!

# %%
nb_accuracy = accuracy_score(
    y_test,
    nb_prediction
)

nb_auc = roc_auc_score(
    y_test,
    nb_probability
)

nb_precision = precision_score(
    y_test,
    nb_prediction
)

nb_recall = recall_score(
    y_test,
    nb_prediction
)

nb_f1 = f1_score(
    y_test,
    nb_prediction
)

nb_mcc = matthews_corrcoef(
    y_test,
    nb_prediction
)

# %%
print("GAUSSIAN NAIVE BAYES RESULTS")
print("--------------------------------")
print("Accuracy  :", round(nb_accuracy, 4))
print("AUC Score :", round(nb_auc, 4))
print("Precision :", round(nb_precision, 4))
print("Recall    :", round(nb_recall, 4))
print("F1 Score  :", round(nb_f1, 4))
print("MCC Score :", round(nb_mcc, 4))
# Out:
# GAUSSIAN NAIVE BAYES RESULTS
# --------------------------------
# Accuracy  : 0.8445
# AUC Score : 0.921
# Precision : 0.8395
# Recall    : 0.935
# F1 Score  : 0.8847
# MCC Score : 0.657

# %%
random_forest = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

random_forest.fit(X_train, y_train)

print("Random Forest trained successfully!")
# Out:
# Random Forest trained successfully!

# %%
rf_prediction = random_forest.predict(X_test)

rf_probability = random_forest.predict_proba(X_test)[:, 1]

print("Random Forest predictions completed!")
# Out:
# Random Forest predictions completed!

# %%
rf_accuracy = accuracy_score(
    y_test,
    rf_prediction
)

rf_auc = roc_auc_score(
    y_test,
    rf_probability
)

rf_precision = precision_score(
    y_test,
    rf_prediction
)

rf_recall = recall_score(
    y_test,
    rf_prediction
)

rf_f1 = f1_score(
    y_test,
    rf_prediction
)

rf_mcc = matthews_corrcoef(
    y_test,
    rf_prediction
)

# %%
print("RANDOM FOREST RESULTS")
print("--------------------------------")
print("Accuracy  :", round(rf_accuracy, 4))
print("AUC Score :", round(rf_auc, 4))
print("Precision :", round(rf_precision, 4))
print("Recall    :", round(rf_recall, 4))
print("F1 Score  :", round(rf_f1, 4))
print("MCC Score :", round(rf_mcc, 4))
# Out:
# RANDOM FOREST RESULTS
# --------------------------------
# Accuracy  : 0.924
# AUC Score : 0.9806
# Precision : 0.9226
# Recall    : 0.9616
# F1 Score  : 0.9417
# MCC Score : 0.8342

# %%
results = pd.DataFrame({

    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "K-Nearest Neighbour",
        "Gaussian Naive Bayes",
        "Random Forest"
    ],

    "Accuracy": [
        logistic_accuracy,
        tree_accuracy,
        knn_accuracy,
        nb_accuracy,
        rf_accuracy
    ],

    "AUC Score": [
        logistic_auc,
        tree_auc,
        knn_auc,
        nb_auc,
        rf_auc
    ],

    "Precision": [
        logistic_precision,
        tree_precision,
        knn_precision,
        nb_precision,
        rf_precision
    ],

    "Recall": [
        logistic_recall,
        tree_recall,
        knn_recall,
        nb_recall,
        rf_recall
    ],

    "F1 Score": [
        logistic_f1,
        tree_f1,
        knn_f1,
        nb_f1,
        rf_f1
    ],

    "MCC Score": [
        logistic_mcc,
        tree_mcc,
        knn_mcc,
        nb_mcc,
        rf_mcc
    ]
})

results = results.round(4)

print(results)
# Out:
#                   Model  Accuracy  AUC Score  Precision  Recall  F1 Score  \
# 0   Logistic Regression    0.8200     0.8920     0.8408  0.8856    0.8626
# 1         Decision Tree    0.8495     0.8369     0.8818  0.8824    0.8821
# 2   K-Nearest Neighbour    0.8625     0.9290     0.8547  0.9451    0.8977
# 3  Gaussian Naive Bayes    0.8445     0.9210     0.8395  0.9350    0.8847
# 4         Random Forest    0.9240     0.9806     0.9226  0.9616    0.9417
#
#    MCC Score
# 0     0.6039
# 1     0.6741
# 2     0.6980
# 3     0.6570
# 4     0.8342

# %%
results.to_csv(
    "ML_Classification_Results.csv",
    index=False
)

print("Results saved successfully!")
# Out:
# Results saved successfully!

# %%
# One new test sample

new_sample = pd.DataFrame([{
    "tau1": 5,
    "tau2": 6,
    "tau3": 7,
    "tau4": 8,
    "p1": 3.0,
    "p2": -1.0,
    "p3": -1.2,
    "p4": -0.8,
    "g1": 0.6,
    "g2": 0.7,
    "g3": 0.8,
    "g4": 0.9
}])

print(new_sample)
# Out:
#    tau1  tau2  tau3  tau4   p1   p2   p3   p4   g1   g2   g3   g4
# 0     5     6     7     8  3.0 -1.0 -1.2 -0.8  0.6  0.7  0.8  0.9

# %%
new_sample_scaled = scaler.transform(new_sample)

# %%
# Logistic Regression
logistic_result = logistic_model.predict(new_sample_scaled)[0]

# Decision Tree
tree_result = decision_tree.predict(new_sample)[0]

# KNN
knn_result = knn_model.predict(new_sample_scaled)[0]

# Naive Bayes
nb_result = naive_bayes.predict(new_sample)[0]

# Random Forest
rf_result = random_forest.predict(new_sample)[0]

# %%
print("Predictions for the new test sample")
print("--------------------------------------")

print("Logistic Regression :", encoder.inverse_transform([logistic_result])[0])
print("Decision Tree       :", encoder.inverse_transform([tree_result])[0])
print("K-Nearest Neighbour:", encoder.inverse_transform([knn_result])[0])
print("Naive Bayes         :", encoder.inverse_transform([nb_result])[0])
print("Random Forest       :", encoder.inverse_transform([rf_result])[0])
# Out:
# Predictions for the new test sample
# --------------------------------------
# Logistic Regression : unstable
# Decision Tree       : unstable
# K-Nearest Neighbour: unstable
# Naive Bayes         : unstable
# Random Forest       : unstable
